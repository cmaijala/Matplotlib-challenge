# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - This study show the effectiveness of Capomulin and Ramicane in reducing tumor volumes compared to Infubinol and Ceftamin.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from pathlib import Path
# %matplotlib notebook
# %matplotlib inline
    
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_data_complete = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])

# Display the data table for preview
mouse_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mouse_count = len(mouse_metadata["Mouse ID"].unique())
mouse_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mice = mouse_data_complete[mouse_data_complete.duplicated(["Mouse ID", "Timepoint"])]["Mouse ID"].unique()
duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_mouse_data = mouse_data_complete[mouse_data_complete["Mouse ID"].isin(duplicate_mice)]
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# Identify duplicate mouse IDs
duplicate_mice = mouse_data_complete[mouse_data_complete.duplicated(["Mouse ID", "Timepoint"])]["Mouse ID"].unique()

# Create a clean DataFrame by dropping rows with duplicate Mouse IDs
clean_mouse_data = mouse_data_complete[~mouse_data_complete["Mouse ID"].isin(duplicate_mice)]

# Display the clean DataFrame
clean_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_count = len(clean_mouse_data["Mouse ID"].unique())
clean_mouse_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.

# Group by 'Drug Regimen'
drug_regimen_group = clean_mouse_data.groupby("Drug Regimen")

# Compute summary statistics
mean = drug_regimen_group["Tumor Volume (mm3)"].mean()
median = drug_regimen_group["Tumor Volume (mm3)"].median()
variance = drug_regimen_group["Tumor Volume (mm3)"].var()
std_dev = drug_regimen_group["Tumor Volume (mm3)"].std()
sem = drug_regimen_group["Tumor Volume (mm3)"].sem()

# Combine the statistics into a DataFrame
tumor_summary_stats = pd.DataFrame({
    "Mean Tumor Volume": mean,
    "Median Tumor Volume": median,
    "Tumor Volume Variance": variance,
    "Tumor Volume Std. Dev.": std_dev,
    "Tumor Volume Std. Err.": sem
})

# Display the summary DataFrame
tumor_summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

advanced_stats = clean_mouse_data[["Tumor Volume (mm3)", "Drug Regimen"]].groupby(["Drug Regimen"]).agg(["mean", "median", "var", "std", "sem"])
advanced_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
# Count the number of rows for each drug regimen

# Group by 'Drug Regimen' and count/sort the number of rows for each regimen
drug_regimen_count = clean_mouse_data.groupby("Drug Regimen").size()
drug_regimen_count_sorted = drug_regimen_count.sort_values(ascending=False)
# Plot using Pandas' plot function
bar_pandas = drug_regimen_count_sorted.plot(kind="bar", figsize=(6, 4))



# Display the plot
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.


# Group by 'Drug Regimen' and count the number of rows for each regimen
drug_regimen_count = clean_mouse_data.groupby("Drug Regimen").size()

# Sort the series in descending order
drug_regimen_count_sorted = drug_regimen_count.sort_values(ascending=False)

# Prepare data for plotting
regimen_names = drug_regimen_count_sorted.index
num_timepoints = drug_regimen_count_sorted.values

# Plot using Pyplot
plt.figure(figsize=(6, 4))
plt.bar(regimen_names, num_timepoints)

# Adding labels and title
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender
unique_mice_gender_count = clean_mouse_data.drop_duplicates(subset='Mouse ID')['Sex'].value_counts()

# Make the pie chart
sex_pie_pandas = unique_mice_gender_count.plot(kind='pie', autopct='%1.1f%%', figsize=(5, 5))

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender
labels = unique_mice_gender_count.index
sizes = unique_mice_gender_count.values

# Make the pie chart
plt.figure(figsize=(5, 5))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=360)
# Out:
# ([<matplotlib.patches.Wedge at 0x2d0234379b0>,
# ...
#  [Text(-0.013934097579310861, 1.0999117423341975, 'Male'),
#   Text(0.013934097579310727, -1.0999117423341975, 'Female')],
#  [Text(-0.007600416861442286, 0.5999518594550168, '50.4%'),
#   Text(0.007600416861442213, -0.5999518594550168, '49.6%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Step 1: Put treatments into a list for the for loop
treatment_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Step 2: Create empty lists to fill with tumor volume data for plotting
tumor_vol_data = []

# Step 3: Loop through each treatment regimen
for drug in treatment_regimens:
    # Locate the rows for each drug regimen and get the last timepoint
    drug_data = clean_mouse_data[clean_mouse_data["Drug Regimen"] == drug]
    final_timepoints = drug_data.groupby("Mouse ID")["Timepoint"].max().reset_index()
    merged_df = pd.merge(final_timepoints, clean_mouse_data, on=["Mouse ID", "Timepoint"])
    
    # Collect the final tumor volumes for the drug
    tumor_volumes = merged_df["Tumor Volume (mm3)"]
    tumor_vol_data.append(tumor_volumes)
    
    # Calculate quartiles and IQR
    quartiles = tumor_volumes.quantile([0.25, 0.50, 0.75])
    IQR = quartiles[0.75] - quartiles[0.25]
    lower_bound = quartiles[0.25] - (1.5 * IQR)
    upper_bound = quartiles[0.75] + (1.5 * IQR)
    
    # Determine outliers
    outliers = tumor_volumes[(tumor_volumes < lower_bound) | (tumor_volumes > upper_bound)]
    
    # Print results
    print(f"{drug}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 5    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
plt.boxplot(tumor_vol_data, labels=treatment_regimens)
plt.title('Final Tumor Volume for Each Treatment Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Final Tumor Volume (mm3)')

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# Step 1: Filter the data for a single mouse treated with Capomulin
mouse_id = clean_mouse_data[clean_mouse_data["Drug Regimen"] == "Capomulin"]["Mouse ID"].unique()[0]  # Get one mouse ID treated with Capomulin
mouse_data = clean_mouse_data[(clean_mouse_data["Mouse ID"] == mouse_id) & (clean_mouse_data["Drug Regimen"] == "Capomulin")]

# Step 2: Plot tumor volume vs. time point
plt.figure(figsize=(6, 4))
plt.plot(mouse_data["Timepoint"], mouse_data["Tumor Volume (mm3)"], marker='o', linestyle='-', color='b')

# Add titles and labels
plt.title(f'Capomulin treatment of mouse {mouse_id}')
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')


# Show the plot

plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
# Step 1: Filter the data for Capomulin regimen
capomulin_data = clean_mouse_data[clean_mouse_data["Drug Regimen"] == "Capomulin"]

# Step 2: Calculate the average tumor volume for each mouse
avg_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean().reset_index()
avg_tumor_volume = avg_tumor_volume.rename(columns={"Tumor Volume (mm3)": "Average Tumor Volume"})

# Step 3: Merge this with mouse metadata to get the weights
capomulin_metadata = pd.merge(avg_tumor_volume, clean_mouse_data[["Mouse ID", "Weight (g)"]].drop_duplicates(), on="Mouse ID")

# Step 4: Plot the data
plt.figure(figsize=(6, 4))
plt.scatter(capomulin_metadata["Weight (g)"], capomulin_metadata["Average Tumor Volume"], color='r', alpha=0.7)

# Add titles and labels
plt.title('Mouse Weight vs. Average Tumor Volume for Capomulin Regimen')
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

# Step 1: Filter the data for Capomulin regimen
capomulin_data = clean_mouse_data[clean_mouse_data["Drug Regimen"] == "Capomulin"]

# Step 2: Calculate the average tumor volume for each mouse
avg_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean().reset_index()
avg_tumor_volume = avg_tumor_volume.rename(columns={"Tumor Volume (mm3)": "Average Tumor Volume"})

# Step 3: Merge this with mouse metadata to get the weights
capomulin_metadata = pd.merge(avg_tumor_volume, clean_mouse_data[["Mouse ID", "Weight (g)"]].drop_duplicates(), on="Mouse ID")

# Extract variables
weights = capomulin_metadata["Weight (g)"]
avg_volumes = capomulin_metadata["Average Tumor Volume"]

# Step 4: Calculate the correlation coefficient
correlation_coefficient, _ = st.pearsonr(weights, avg_volumes)

# Step 5: Fit a linear regression model
slope, intercept, r_value, p_value, std_err = st.linregress(weights, avg_volumes)

# Step 6: Generate regression line values
regression_line = slope * weights + intercept

# Step 7: Plot the data and the regression line
plt.figure(figsize=(6, 4))
plt.scatter(weights, avg_volumes, color='r', alpha=0.7, label='Mouse Weight vs. Average Tumor Volume')
plt.plot(weights, regression_line, color='blue', linewidth=2, label='Linear Regression Line')

# Add titles and labels
plt.title('Mouse Weight vs. Average Tumor Volume for Capomulin Regimen')
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# Print the correlation coefficient and regression line equation
print(f"Correlation Coefficient: {correlation_coefficient:.2f}")
print(f"Linear Regression Line: y = {slope:.2f}x + {intercept:.2f}")
# Out:
# Correlation Coefficient: 0.84
# Linear Regression Line: y = 0.95x + 21.55
